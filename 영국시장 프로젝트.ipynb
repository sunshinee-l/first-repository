# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

brand = pd.read_csv('brand.csv')
car = pd.read_csv('cars.csv')

car.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history
# 0             NaN
# 1            Full
# 2             NaN
# 3            Full
# ...

# %%
car['title'].unique()
# Out:
# array(['SKODA FABIA', 'VAUXHALL CORSA', 'HYUNDAI I30', 'MINI HATCH',
#        'HYUNDAI COUPE', 'FORD FOCUS', 'VOLVO 740', 'PEUGEOT 207',
#        'FORD FIESTA', 'VAUXHALL INSIGNIA', 'BMW 3 SERIES', 'CITROEN C1',
#        'CITROEN C4', 'VAUXHALL ASTRA', 'FORD MONDEO',
#        'MERCEDES-BENZ A180', 'PEUGEOT 407', 'FORD KA',
#        'MERCEDES-BENZ A CLASS', 'MAZDA MAZDA2', 'SAAB 9-3',
#        'VOLKSWAGEN POLO', 'BMW 1 SERIES', 'HONDA ACCORD',
#        'VOLKSWAGEN BEETLE', 'MG MG6', 'FORD C-MAX', 'HONDA CIVIC',
#        'TOYOTA AURIS', 'VOLVO S40', 'SEAT IBIZA', 'PEUGEOT 308',
#        'VAUXHALL MERIVA', 'MERCEDES-BENZ B CLASS', 'MAZDA MAZDA3',
#        'NISSAN 350 Z', 'ALFA ROMEO MITO', 'RENAULT FLUENCE',
#        'VOLKSWAGEN PASSAT', 'KIA SPORTAGE', 'CITROEN XM',
#        'VAUXHALL ANTARA', 'NISSAN NOTE', 'BMW 5 SERIES', 'HONDA CR-V',
#        'PROTON SAVVY', 'NISSAN MICRA', 'FIAT PANDA', 'RENAULT MEGANE',
#        'RENAULT CLIO', 'HYUNDAI I20', 'CITROEN C3', 'AUDI A6 SALOON',
# ...

# %%
brand['title'] = brand['title'].str.upper()

# %%
car['brands'] = car['title'].str.split().str[0]

car.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history    brands
# 0             NaN     SKODA
# 1            Full  VAUXHALL
# ...

# %%
#data = car.merge(brand, on= 'title', how = 'left') #1
brand = brand.rename(columns = {'title': 'brands'})

data = car.merge(brand, on ='brands', how = 'left')
data.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history    brands         country
# 0             NaN     SKODA  Czech Republic
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3687 entries, 0 to 3686
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              3687 non-null   object
#  1   Price              3687 non-null   int64
#  2   Mileage(miles)     3687 non-null   int64
#  3   Registration_Year  3687 non-null   int64
#  4   Previous Owners    2276 non-null   float64
#  5   Fuel type          3687 non-null   object
#  6   Body type          3687 non-null   object
#  7   Engine             3642 non-null   object
#  8   Gearbox            3687 non-null   object
#  9   Doors              3662 non-null   float64
#  10  Seats              3652 non-null   float64
#  11  Emission Class     3600 non-null   object
#  12  Service history    540 non-null    object
#  13  brands             3687 non-null   object
#  14  country            3687 non-null   object
# dtypes: float64(3), int64(3), object(9)
# ...

# %%
data['Engine'] = data['Engine'].str.replace('L','').astype(float)

# %%
data.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type  Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback     1.4  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback     1.2  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback     1.4  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback     1.4  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback     1.3  Manual    5.0    5.0         Euro 5
#
#   Service history    brands         country
# 0             NaN     SKODA  Czech Republic
# ...

# %%
data['Emission Class'] = data['Emission Class'].str.split(' ').str[1].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3687 entries, 0 to 3686
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              3687 non-null   object
#  1   Price              3687 non-null   int64
#  2   Mileage(miles)     3687 non-null   int64
#  3   Registration_Year  3687 non-null   int64
#  4   Previous Owners    2276 non-null   float64
#  5   Fuel type          3687 non-null   object
#  6   Body type          3687 non-null   object
#  7   Engine             3642 non-null   float64
#  8   Gearbox            3687 non-null   object
#  9   Doors              3662 non-null   float64
#  10  Seats              3652 non-null   float64
#  11  Emission Class     3600 non-null   float64
#  12  Service history    540 non-null    object
#  13  brands             3687 non-null   object
#  14  country            3687 non-null   object
# dtypes: float64(5), int64(3), object(7)
# ...

# %%
data.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type  Engine Gearbox  Doors  Seats  Emission Class  \
# 0    Diesel  Hatchback     1.4  Manual    5.0    5.0             6.0
# 1    Petrol  Hatchback     1.2  Manual    3.0    5.0             4.0
# 2    Petrol  Hatchback     1.4  Manual    5.0    5.0             5.0
# 3    Petrol  Hatchback     1.4  Manual    3.0    4.0             4.0
# 4    Diesel  Hatchback     1.3  Manual    5.0    5.0             5.0
#
#   Service history    brands         country
# ...

# %%
data.isna().sum()
# Out:
# title                   0
# Price                   0
# Mileage(miles)          0
# Registration_Year       0
# Previous Owners      1411
# Fuel type               0
# Body type               0
# Engine                 45
# Gearbox                 0
# Doors                  25
# Seats                  35
# Emission Class         87
# Service history      3147
# brands                  0
# country                 0
# dtype: int64

# %%
data['Service history'].unique()
# Out:
# array([nan, 'Full'], dtype=object)

# %%
data['Service history'].fillna('Unknown')
# Out:
# 0       Unknown
# 1          Full
# 2       Unknown
# 3          Full
# 4       Unknown
#          ...
# 3682    Unknown
# 3683    Unknown
# 3684    Unknown
# 3685       Full
# 3686    Unknown
# Name: Service history, Length: 3687, dtype: object

# %%
#data = data.drop(columns= ['country'])

# %%
data.isna().mean()
# Out:
# title                0.000000
# Price                0.000000
# Mileage(miles)       0.000000
# Registration_Year    0.000000
# Previous Owners      0.382696
# Fuel type            0.000000
# Body type            0.000000
# Engine               0.012205
# Gearbox              0.000000
# Doors                0.006781
# Seats                0.009493
# Emission Class       0.023596
# Service history      0.853539
# brands               0.000000
# country              0.000000
# dtype: float64

# %%
data['Previous Owners'].unique()
data['Previous Owners'].fillna(data['Previous Owners'].median())
# Out:
# 0       3.0
# 1       4.0
# 2       3.0
# 3       5.0
# 4       3.0
#        ...
# 3682    4.0
# 3683    3.0
# 3684    3.0
# 3685    3.0
# 3686    7.0
# Name: Previous Owners, Length: 3687, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
data['Price'].mean()
data['Price'].std()
(data['Price'] - data['Price'].mean()) / data['Price'].std() #ss
# Out:
# 0       0.248335
# 1      -0.957968
# 2      -1.079826
# 3      -0.757104
# 4      -1.068444
#           ...
# 3682   -0.980287
# 3683    0.268422
# 3684   -0.400011
# 3685   -0.981402
# 3686   -0.845261
# Name: Price, Length: 3687, dtype: float64

# %%
#rs
(data['Price'] - data['Price'].quantile(0.5)) /(data['Price'].quantile(0.75) - data['Price'].quantile(0.25))
# Out:
# 0       0.526794
# 1      -0.455041
# 2      -0.554223
# 3      -0.291553
# 4      -0.544959
#           ...
# 3682   -0.473206
# 3683    0.543143
# 3684   -0.000908
# 3685   -0.474114
# 3686   -0.363306
# Name: Price, Length: 3687, dtype: float64

# %%
#mm
(data['Price'] - data['Price'].min()) / (data['Price'].max() - data['Price'].min())
# Out:
# 0       0.194030
# 1       0.032687
# 2       0.016388
# 3       0.059552
# 4       0.017910
#           ...
# 3682    0.029701
# 3683    0.196716
# 3684    0.107313
# 3685    0.029552
# 3686    0.047761
# Name: Price, Length: 3687, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler,RobustScaler,MinMaxScaler
ss = StandardScaler()
rs = RobustScaler()
mm = MinMaxScaler()

# %%
ss
# Out:
# StandardScaler()

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
from sklearn.impute import SimpleImputer
numeric_data = data.select_dtypes(include=['int64', 'float64'])

imputer = SimpleImputer(strategy='mean')
numeric_data_imputed = imputer.fit_transform(numeric_data)

pca.fit(numeric_data_imputed)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['Emission Class']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# PCA()

# %%
pca = PCA(2)

# %%
pd.DataFrame(pca.fit_transform(numeric_data_imputed), columns= ['PC1', 'PC2'])
# Out:
#                PC1          PC2
# 0    -11185.009783   472.166472
# 1      7490.632318 -3869.179566
# 2     55857.290251 -1638.319791
# 3     15571.628140 -2503.593789
# 4      3939.911421 -4568.913265
# ...            ...          ...
# 3682  -4866.262570 -4679.017527
# 3683  37540.530916  3360.679479
# 3684  57679.352265  1517.343325
# 3685  97952.597998  1220.989051
# 3686   1047.246825 -3733.395460
#
# [3687 rows x 2 columns]

# %%
(pca.explained_variance_ratio_).sum()
# Out:
# np.float64(0.9999999904931542)

# %%
pca = PCA(1)
pd.DataFrame(pca.fit_transform(numeric_data_imputed), columns= ['PC1'])
# Out:
#                PC1
# 0    -11185.009783
# 1      7490.632318
# 2     55857.290251
# 3     15571.628140
# 4      3939.911421
# ...            ...
# 3682  -4866.262570
# 3683  37540.530916
# 3684  57679.352265
# 3685  97952.597998
# 3686   1047.246825
#
# [3687 rows x 1 columns]

# %%
(pca.explained_variance_ratio_)[0]
# Out:
# np.float64(0.9904683223397838)

# %%
numeric_data = data.select_dtypes(include=['int64', 'float64'])
numeric_data.corr()
# Out:
#                       Price  Mileage(miles)  Registration_Year  \
# Price              1.000000       -0.500358           0.722971
# Mileage(miles)    -0.500358        1.000000          -0.410781
# Registration_Year  0.722971       -0.410781           1.000000
# Previous Owners   -0.479424        0.316160          -0.501045
# Engine            -0.022692        0.331722          -0.290452
# Doors              0.113335       -0.037024           0.219365
# Seats             -0.027393        0.095271           0.037166
# Emission Class     0.697992       -0.378377           0.920095
#
#                    Previous Owners    Engine     Doors     Seats  \
# Price                    -0.479424 -0.022692  0.113335 -0.027393
# Mileage(miles)            0.316160  0.331722 -0.037024  0.095271
# Registration_Year        -0.501045 -0.290452  0.219365  0.037166
# Previous Owners           1.000000  0.195676 -0.153262 -0.029338
# Engine                    0.195676  1.000000 -0.061935  0.072934
# ...

# %%
corr_matrix.stack().abs().idxmax()
# Out:
# ('Price', 'Registration_Year')

# %%
data.groupby('country')['brands'].count()
# Out:
# country
# Czech Republic     63
# France            522
# Germany           863
# Italy             128
# Japan             641
# Malaysia            3
# Romania            14
# South Korea       178
# Spain              60
# Sweden             47
# United Kingdom    729
# United States     439
# Name: brands, dtype: int64
